# %% [markdown]
# <a href="https://colab.research.google.com/github/Masciel-Sevilla/CalculadoraVLSM_MascielSevilla/blob/master/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, regularizers
import numpy as np
import matplotlib.pyplot as plt
import os
from glob import glob

# --- Configuración del modelo ---
IMG_HEIGHT = 128
IMG_WIDTH = 128
NUM_CLASSES = 6  # 0-background, 1-Cow-tongue, 2-Dandelion, 3-Kikuyo, 4-Other, 5-Potato
BATCH_SIZE = 16
EPOCHS = 50
LEARNING_RATE = 1e-4

# --- Paths ---
BASE_PATH = '/content/Balanced'
TRAIN_IMAGES_PATH = os.path.join(BASE_PATH, 'train/images')
TRAIN_MASKS_PATH = os.path.join(BASE_PATH, 'train/masks')
VAL_IMAGES_PATH = os.path.join(BASE_PATH, 'val/images')
VAL_MASKS_PATH = os.path.join(BASE_PATH, 'val/masks')

# --- Módulos del modelo ---
class ASPPModule(layers.Layer):
    def __init__(self, filters=64, **kwargs): # Changed from _init_ to __init__
        super(ASPPModule, self).__init__(**kwargs)
        self.filters = filters

        self.conv_1x1 = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1 = layers.BatchNormalization()
        self.relu_1x1 = layers.ReLU()

        self.conv_3x3_6 = layers.Conv2D(filters, 3, padding='same', dilation_rate=6, use_bias=False)
        self.bn_3x3_6 = layers.BatchNormalization()
        self.relu_3x3_6 = layers.ReLU()

        self.conv_3x3_12 = layers.Conv2D(filters, 3, padding='same', dilation_rate=12, use_bias=False)
        self.bn_3x3_12 = layers.BatchNormalization()
        self.relu_3x3_12 = layers.ReLU()

        self.global_avg_pool = layers.GlobalAveragePooling2D(keepdims=True)
        self.conv_1x1_gap = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1_gap = layers.BatchNormalization()
        self.relu_1x1_gap = layers.ReLU()

        self.conv_final = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_final = layers.BatchNormalization()
        self.relu_final = layers.ReLU()
        # FIX: Instantiate Dropout once in _init_
        self.dropout = layers.Dropout(0.3)

    def call(self, inputs, training=None):
        input_shape = tf.shape(inputs) # This is fine as it's a tf.Tensor shape

        conv_1x1 = self.relu_1x1(self.bn_1x1(self.conv_1x1(inputs), training=training))
        conv_3x3_6 = self.relu_3x3_6(self.bn_3x3_6(self.conv_3x3_6(inputs), training=training))
        conv_3x3_12 = self.relu_3x3_12(self.bn_3x3_12(self.conv_3x3_12(inputs), training=training))

        gap = self.global_avg_pool(inputs)
        gap = self.relu_1x1_gap(self.bn_1x1_gap(self.conv_1x1_gap(gap), training=training))
        # This tf.image.resize is fine because it's operating on a KerasTensor directly
        # and doesn't create new variables internally per call.
        gap = tf.image.resize(gap, [input_shape[1], input_shape[2]], method='bilinear')

        concat = layers.Concatenate()([conv_1x1, conv_3x3_6, conv_3x3_12, gap])

        output = self.relu_final(self.bn_final(self.conv_final(concat), training=training))
        # FIX: Call the instantiated dropout layer
        output = self.dropout(output, training=training)

        return output

class DeformableAttention(layers.Layer):
    def __init__(self, filters, **kwargs): # Changed from _init_ to __init__
        super(DeformableAttention, self).__init__(**kwargs)
        self.filters = filters

        # FIX: Instantiate Dropout here if you add it to this layer later
        # self.dropout = layers.Dropout(0.3) # Example if you needed it here

    def build(self, input_shape):
        self.attention_conv = layers.Conv2D(self.filters, 1, padding='same', activation='sigmoid', name='attention_weights_conv', use_bias=False)
        self.bn_attention = layers.BatchNormalization()

        self.feature_conv = layers.Conv2D(self.filters, 3, padding='same', name='feature_processing_conv', use_bias=False)
        self.bn_feature = layers.BatchNormalization()
        self.relu_feature = layers.ReLU()

        super(DeformableAttention, self).build(input_shape)

    def call(self, inputs, training=None):
        attention_weights = self.bn_attention(self.attention_conv(inputs), training=training)
        features = self.relu_feature(self.bn_feature(self.feature_conv(inputs), training=training))
        attended_features = features * attention_weights
        return attended_features

def create_efficient_backbone(input_shape):
    base_model = tf.keras.applications.EfficientNetV2B0( # You can change this to B1, B2, etc.
        input_shape=input_shape,
        weights='imagenet',
        include_top=False
    )
    base_model.trainable = False

    layer_names = [
        'block1a_project_activation',
        'block2a_expand_activation',
        'block3a_expand_activation',
        'block4a_expand_activation',
        'top_activation'
    ]

    outputs = [base_model.get_layer(name).output for name in layer_names]

    return Model(inputs=base_model.input, outputs=outputs, name='EfficientNetV2B0_Backbone')

def create_weed_detection_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=NUM_CLASSES):
    inputs = layers.Input(shape=input_shape)

    backbone = create_efficient_backbone(input_shape)
    backbone_features = backbone(inputs)

    deep_features = backbone_features[-1]
    mid_features = backbone_features[-3]

    aspp_features = ASPPModule(filters=64)(deep_features)
    attended_features = DeformableAttention(filters=64)(aspp_features)

    # Decoder Path: Use layers.ReLU() explicitly after BatchNormalization
    decoder_features = layers.Conv2DTranspose(64, 2, strides=2, padding='same', use_bias=False)(attended_features)
    decoder_features = layers.BatchNormalization()(decoder_features)
    decoder_features = layers.ReLU()(decoder_features)
    # FIX: Instantiate Dropout before use, or apply it directly if it's a one-off
    # For layers outside custom classes, applying directly is fine if not creating variables per call in a loop.
    # However, it's generally safer to instantiate if you're unsure or use it multiple times.
    # Here, for simplicity and consistency with the fix, we will instantiate it.
    decoder_dropout1 = layers.Dropout(0.3)
    decoder_features = decoder_dropout1(decoder_features)


    decoder_features = layers.Conv2DTranspose(64, 2, strides=2, padding='same', use_bias=False)(decoder_features)
    decoder_features = layers.BatchNormalization()(decoder_features)
    decoder_features = layers.ReLU()(decoder_features)

    mid_processed = layers.Conv2D(32, 1, padding='same', use_bias=False)(mid_features)
    mid_processed = layers.BatchNormalization()(mid_processed)
    mid_processed = layers.ReLU()(mid_processed)

    decoder_concat = layers.Concatenate()([decoder_features, mid_processed])

    decoder_conv1 = layers.Conv2D(64, 3, padding='same', use_bias=False)(decoder_concat)
    decoder_conv1 = layers.BatchNormalization()(decoder_conv1)
    decoder_conv1 = layers.ReLU()(decoder_conv1)
    # FIX: Instantiate Dropout before use
    decoder_dropout2 = layers.Dropout(0.3)
    decoder_conv1 = decoder_dropout2(decoder_conv1)

    decoder_conv2 = layers.Conv2D(64, 3, padding='same', use_bias=False)(decoder_conv1)
    decoder_conv2 = layers.BatchNormalization()(decoder_conv2)
    decoder_conv2 = layers.ReLU()(decoder_conv2)

    final_upsample = layers.Conv2DTranspose(NUM_CLASSES, 2, strides=2, padding='same', use_bias=False)(decoder_conv2)
    final_upsample = layers.BatchNormalization()(final_upsample)
    final_upsample = layers.ReLU()(final_upsample)

    final_upsample = layers.Conv2DTranspose(NUM_CLASSES, 2, strides=2, padding='same', use_bias=False)(final_upsample)
    final_upsample = layers.BatchNormalization()(final_upsample)
    final_upsample = layers.ReLU()(final_upsample)

    final_upsample = layers.Conv2DTranspose(NUM_CLASSES, 2, strides=2, padding='same', use_bias=False)(final_upsample)
    final_upsample = layers.BatchNormalization()(final_upsample)
    final_upsample = layers.ReLU()(final_upsample)

    outputs = layers.Conv2D(num_classes, 1, padding='same', activation='softmax', name='segmentation_output')(final_upsample)

    model = Model(inputs=inputs, outputs=outputs, name='WeedDetectionModel')

    return model

# --- Métricas y Funciones de Pérdida (Resto del código permanece igual) ---
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(tf.cast(y_true, tf.float32), [-1, NUM_CLASSES])
    y_pred_f = tf.reshape(tf.cast(y_pred, tf.float32), [-1, NUM_CLASSES])

    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
    dice_scores = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f, axis=0) + tf.reduce_sum(y_pred_f, axis=0) + smooth)

    return tf.reduce_mean(dice_scores)

def weighted_categorical_crossentropy(weights):
    def loss(y_true, y_pred):
        y_pred /= tf.reduce_sum(y_pred, axis=-1, keepdims=True)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        loss = y_true * tf.math.log(y_pred) * weights
        return -tf.reduce_sum(loss, axis=-1)

    return loss

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    class_weights = tf.constant([0.5, 2.5, 2.5, 1.0, 1.0, 2.5])
    ce_loss = weighted_categorical_crossentropy(class_weights)(y_true, y_pred)
    d_loss = dice_loss(y_true, y_pred)
    return ce_loss + (1.0 * d_loss)

def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3]) - intersection

    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou)

def iou_per_class(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2])
    union = tf.reduce_sum(y_true, axis=[1, 2]) + tf.reduce_sum(y_pred, axis=[1, 2]) - intersection

    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou, axis=0)

# --- Carga y Preprocesamiento de Datos (Resto del código permanece igual) ---
def load_and_preprocess_data(images_path, masks_path):
    def load_image(image_path):
        image = tf.io.read_file(image_path)
        image = tf.image.decode_image(image, channels=3, expand_animations=False)
        image.set_shape([None, None, 3])
        image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH], method='bilinear')
        image = tf.cast(image, tf.float32) / 255.0
        return image

    def load_mask(mask_path):
        mask = tf.io.read_file(mask_path)
        mask = tf.image.decode_png(mask, channels=1)
        mask = tf.image.resize(mask, [IMG_HEIGHT, IMG_WIDTH], method='nearest')
        mask = tf.cast(mask, tf.int32)
        mask = tf.squeeze(mask, axis=-1)
        mask = tf.one_hot(mask, NUM_CLASSES)
        return mask

    image_paths = sorted(glob(os.path.join(images_path, '*.jpg')))
    mask_paths = sorted(glob(os.path.join(masks_path, '*.png')))

    if not image_paths:
        raise FileNotFoundError(f"No image files found in: {images_path}. Check path and file extensions.")
    if not mask_paths:
        raise FileNotFoundError(f"No mask files found in: {masks_path}. Check path and file extensions.")

    image_names = [os.path.basename(p).split('.')[0] for p in image_paths]
    mask_names = [os.path.basename(p).split('.')[0] for p in mask_paths]

    if set(image_names) != set(mask_names):
        print("Warning: Image and mask filenames do not match exactly. This might lead to misaligned data.")

    if len(image_paths) != len(mask_paths):
        print(f"DEBUG: Found {len(image_paths)} images and {len(mask_paths)} masks.")
        print("DEBUG: First 5 image files:", [os.path.basename(p) for p in image_paths[:5]])
        print("DEBUG: First 5 mask files:", [os.path.basename(p) for p in mask_paths[:5]])

    print(f"Found {len(image_paths)} images and {len(mask_paths)} masks")

    image_ds = tf.data.Dataset.from_tensor_slices(image_paths).map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
    mask_ds = tf.data.Dataset.from_tensor_slices(mask_paths).map(load_mask, num_parallel_calls=tf.data.AUTOTUNE)

    dataset = tf.data.Dataset.zip((image_ds, mask_ds))

    return dataset

def augment_data(image, mask):
    if tf.random.uniform([]) > 0.5:
        image = tf.image.flip_left_right(image)
        mask = tf.image.flip_left_right(mask)

    if tf.random.uniform([]) > 0.5:
        image = tf.image.flip_up_down(image)
        mask = tf.image.flip_up_down(mask)

    if tf.random.uniform([]) > 0.5:
        k = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        image = tf.image.rot90(image, k)
        mask = tf.image.rot90(mask, k)

    image = tf.image.random_brightness(image, max_delta=0.3)
    image = tf.image.random_contrast(image, lower=0.7, upper=1.3)
    image = tf.image.random_hue(image, max_delta=0.1)
    image = tf.image.random_saturation(image, lower=0.7, upper=1.3)

    image = tf.clip_by_value(image, 0.0, 1.0)

    return image, mask

def create_datasets():
    train_dataset = load_and_preprocess_data(TRAIN_IMAGES_PATH, TRAIN_MASKS_PATH)
    val_dataset = load_and_preprocess_data(VAL_IMAGES_PATH, VAL_MASKS_PATH)

    train_dataset = train_dataset.cache()
    val_dataset = val_dataset.cache()

    train_dataset = train_dataset.shuffle(buffer_size=1000).map(augment_data, num_parallel_calls=tf.data.AUTOTUNE)
    train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    val_dataset = val_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    return train_dataset, val_dataset

def train_model(train_dataset, val_dataset, model_save_path='best_weed_model.h5'):
    model = create_weed_detection_model()
    model.summary()

    optimizer = tf.keras.optimizers.AdamW(learning_rate=LEARNING_RATE, weight_decay=1e-4)

    model.compile(
        optimizer=optimizer,
        loss=combined_loss,
        metrics=[dice_coefficient, iou_metric, 'accuracy']
    )

    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(
            model_save_path,
            monitor='val_dice_coefficient',
            save_best_only=True,
            mode='max',
            verbose=1
        ),
        tf.keras.callbacks.EarlyStopping(
            monitor='val_dice_coefficient',
            patience=30,
            mode='max',
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=15,
            min_lr=1e-8,
            verbose=1
        ),
    ]

    print(f"Starting training for {EPOCHS} epochs...")
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=val_dataset,
        callbacks=callbacks,
        verbose=1
    )

    return model, history

def visualize_predictions(model, val_dataset, num_samples=4):
    class_names = ['Background', 'Cow-tongue', 'Dandelion', 'Kikuyo', 'Other', 'Potato']

    print(f"Visualizing {num_samples} samples from the validation set...")

    for images, masks in val_dataset.take(1):
        predictions = model.predict(images)

        fig, axes = plt.subplots(num_samples, 3, figsize=(15, 5 * num_samples))

        for i in range(min(num_samples, images.shape[0])):
            axes[i, 0].imshow(images[i])
            axes[i, 0].set_title('Original Image')
            axes[i, 0].axis('off')

            true_mask = np.argmax(masks[i].numpy(), axis=-1)
            axes[i, 1].imshow(true_mask, cmap='tab10', vmin=0, vmax=NUM_CLASSES - 1)
            axes[i, 1].set_title('True Mask')
            axes[i, 1].axis('off')

            pred_mask = np.argmax(predictions[i], axis=-1)
            axes[i, 2].imshow(pred_mask, cmap='tab10', vmin=0, vmax=NUM_CLASSES - 1)
            axes[i, 2].set_title('Predicted Mask')
            axes[i, 2].axis('off')

        plt.tight_layout()
        plt.show()
        break

if __name__ == "__main__":
    if not os.path.exists(TRAIN_IMAGES_PATH):
        print(f"Error: La ruta de imágenes de entrenamiento NO existe: {TRAIN_IMAGES_PATH}")
        exit()
    if not os.path.exists(TRAIN_MASKS_PATH):
        print(f"Error: La ruta de máscaras de entrenamiento NO existe: {TRAIN_MASKS_PATH}")
        exit()
    if not os.path.exists(VAL_IMAGES_PATH):
        print(f"Error: La ruta de imágenes de validación NO existe: {VAL_IMAGES_PATH}")
        exit()
    if not os.path.exists(VAL_MASKS_PATH):
        print(f"Error: La ruta de máscaras de validación NO existe: {VAL_MASKS_PATH}")
        exit()

    print("Creando datasets...")
    train_ds, val_ds = create_datasets()

    print("Entrenando modelo...")
    model, history = train_model(train_ds, val_ds)

    print("Visualizando predicciones...")
    visualize_predictions(model, val_ds)

    print("¡Entrenamiento completado! El mejor modelo se guardó como 'best_weed_model.h5'")

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['dice_coefficient'], label='Dice Coeff (Train)')
    plt.plot(history.history['val_dice_coefficient'], label='Dice Coeff (Validation)')
    plt.title('Dice Coefficient over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Dice Coefficient')
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Loss (Train)')
    plt.plot(history.history['val_loss'], label='Loss (Validation)')
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.show()

    print("\nEvaluando el modelo final en el conjunto de validación:")
    final_metrics = model.evaluate(val_ds)
    print(f"Validation Loss: {final_metrics[0]:.4f}")
    print(f"Validation Dice Coefficient: {final_metrics[1]:.4f}")
    print(f"Validation IoU: {final_metrics[2]:.4f}")
    print(f"Validation Accuracy: {final_metrics[3]:.4f}")

    iou_per_class_values = []
    for images, masks in val_ds.take(len(list(val_ds))):
        predictions = model.predict(images, verbose=0)
        iou_per_class_values.append(iou_per_class(masks, predictions))

    iou_per_class_values = tf.reduce_mean(tf.stack(iou_per_class_values), axis=0).numpy()

    class_names = ['Background', 'Cow-tongue', 'Dandelion', 'Kikuyo', 'Other', 'Potato']
    for i, iou in enumerate(iou_per_class_values):
        print(f"IoU for {class_names[i]}: {iou:.4f}")
# Out:
# Creando datasets...
# Found 1680 images and 1680 masks
# Found 210 images and 210 masks
# Entrenando modelo...
# Model: "WeedDetectionModel"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_16      │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ EfficientNetV2B0_B… │ [(None, 64, 64,   │  5,919,312 │ input_layer_16[0… │
# │ (Functional)        │ 16), (None, 32,   │            │                   │
# │                     │ 32, 64), (None,   │            │                   │
# │                     │ 16, 16, 128),     │            │                   │
# │                     │ (None, 16, 16,    │            │                   │
# │                     │ 192), (None, 4,   │            │                   │
# │                     │ 4, 1280)]         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aspp_module_8       │ (None, 4, 4, 64)  │  1,656,064 │ EfficientNetV2B0… │
# │ (ASPPModule)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deformable_attenti… │ (None, 4, 4, 64)  │     41,472 │ aspp_module_8[0]… │
# │ (DeformableAttenti… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_35 │ (None, 8, 8, 64)  │     16,384 │ deformable_atten… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_88 (ReLU)     │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 8, 8, 64)  │          0 │ re_lu_88[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_36 │ (None, 16, 16,    │     16,384 │ dropout_24[0][0]  │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_71 (Conv2D)  │ (None, 16, 16,    │      4,096 │ EfficientNetV2B0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_71[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_89 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_90 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_51      │ (None, 16, 16,    │          0 │ re_lu_89[0][0],   │
# │ (Concatenate)       │ 96)               │            │ re_lu_90[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_72 (Conv2D)  │ (None, 16, 16,    │     55,296 │ concatenate_51[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_72[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_91 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 16, 16,    │          0 │ re_lu_91[0][0]    │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_73 (Conv2D)  │ (None, 16, 16,    │     36,864 │ dropout_25[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_73[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_92 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_37 │ (None, 32, 32, 6) │      1,536 │ re_lu_92[0][0]    │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32, 6) │         24 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_93 (ReLU)     │ (None, 32, 32, 6) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_38 │ (None, 64, 64, 6) │        144 │ re_lu_93[0][0]    │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64, 6) │         24 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_94 (ReLU)     │ (None, 64, 64, 6) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_39 │ (None, 128, 128,  │        144 │ re_lu_94[0][0]    │
# │ (Conv2DTranspose)   │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         24 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_95 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segmentation_output │ (None, 128, 128,  │         42 │ re_lu_95[0][0]    │
# │ (Conv2D)            │ 6)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,748,962 (29.56 MB)
#  Trainable params: 1,828,142 (6.97 MB)
#  Non-trainable params: 5,920,820 (22.59 MB)
# Starting training for 50 epochs...
# Epoch 1/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.3354 - dice_coefficient: 0.0922 - iou_metric: 0.2022 - loss: 2.3321
# Epoch 1: val_dice_coefficient improved from -inf to 0.08887, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 59s 153ms/step - accuracy: 0.3359 - dice_coefficient: 0.0922 - iou_metric: 0.2026 - loss: 2.3317 - val_accuracy: 0.5665 - val_dice_coefficient: 0.0889 - val_iou_metric: 0.3980 - val_loss: 2.2932 - learning_rate: 1.0000e-04
# Epoch 2/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4288 - dice_coefficient: 0.0985 - iou_metric: 0.2745 - loss: 2.2534
# Epoch 2: val_dice_coefficient improved from 0.08887 to 0.09398, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - accuracy: 0.4293 - dice_coefficient: 0.0985 - iou_metric: 0.2749 - loss: 2.2529 - val_accuracy: 0.6024 - val_dice_coefficient: 0.0940 - val_iou_metric: 0.4355 - val_loss: 2.2407 - learning_rate: 1.0000e-04
# Epoch 3/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5042 - dice_coefficient: 0.1041 - iou_metric: 0.3398 - loss: 2.1916
# Epoch 3: val_dice_coefficient did not improve from 0.09398
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.5045 - dice_coefficient: 0.1041 - iou_metric: 0.3401 - loss: 2.1913 - val_accuracy: 0.4516 - val_dice_coefficient: 0.0923 - val_iou_metric: 0.2919 - val_loss: 2.2778 - learning_rate: 1.0000e-04
# Epoch 4/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5699 - dice_coefficient: 0.1097 - iou_metric: 0.4045 - loss: 2.1596
# Epoch 4: val_dice_coefficient did not improve from 0.09398
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.5702 - dice_coefficient: 0.1097 - iou_metric: 0.4048 - loss: 2.1589 - val_accuracy: 0.3631 - val_dice_coefficient: 0.0913 - val_iou_metric: 0.2213 - val_loss: 2.3248 - learning_rate: 1.0000e-04
# Epoch 5/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6435 - dice_coefficient: 0.1138 - iou_metric: 0.4884 - loss: 2.0768
# Epoch 5: val_dice_coefficient improved from 0.09398 to 0.09426, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.6441 - dice_coefficient: 0.1139 - iou_metric: 0.4892 - loss: 2.0766 - val_accuracy: 0.3356 - val_dice_coefficient: 0.0943 - val_iou_metric: 0.2005 - val_loss: 2.2522 - learning_rate: 1.0000e-04
# Epoch 6/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7106 - dice_coefficient: 0.1210 - iou_metric: 0.5798 - loss: 2.0347
# Epoch 6: val_dice_coefficient improved from 0.09426 to 0.09599, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.7107 - dice_coefficient: 0.1211 - iou_metric: 0.5799 - loss: 2.0346 - val_accuracy: 0.3416 - val_dice_coefficient: 0.0960 - val_iou_metric: 0.2049 - val_loss: 2.2154 - learning_rate: 1.0000e-04
# Epoch 7/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7447 - dice_coefficient: 0.1264 - iou_metric: 0.6222 - loss: 1.9733
# Epoch 7: val_dice_coefficient improved from 0.09599 to 0.09679, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.7448 - dice_coefficient: 0.1264 - iou_metric: 0.6223 - loss: 1.9732 - val_accuracy: 0.3395 - val_dice_coefficient: 0.0968 - val_iou_metric: 0.2035 - val_loss: 2.1945 - learning_rate: 1.0000e-04
# Epoch 8/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7681 - dice_coefficient: 0.1340 - iou_metric: 0.6513 - loss: 1.9451
# Epoch 8: val_dice_coefficient improved from 0.09679 to 0.10369, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.7682 - dice_coefficient: 0.1340 - iou_metric: 0.6514 - loss: 1.9446 - val_accuracy: 0.3880 - val_dice_coefficient: 0.1037 - val_iou_metric: 0.2381 - val_loss: 2.1099 - learning_rate: 1.0000e-04
# Epoch 9/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7920 - dice_coefficient: 0.1400 - iou_metric: 0.6809 - loss: 1.9049
# Epoch 9: val_dice_coefficient did not improve from 0.10369
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.7920 - dice_coefficient: 0.1400 - iou_metric: 0.6809 - loss: 1.9046 - val_accuracy: 0.3569 - val_dice_coefficient: 0.0991 - val_iou_metric: 0.2157 - val_loss: 2.1440 - learning_rate: 1.0000e-04
# Epoch 10/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8033 - dice_coefficient: 0.1438 - iou_metric: 0.6941 - loss: 1.8499
# Epoch 10: val_dice_coefficient improved from 0.10369 to 0.14366, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.8035 - dice_coefficient: 0.1438 - iou_metric: 0.6943 - loss: 1.8498 - val_accuracy: 0.7919 - val_dice_coefficient: 0.1437 - val_iou_metric: 0.6675 - val_loss: 1.8109 - learning_rate: 1.0000e-04
# Epoch 11/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8160 - dice_coefficient: 0.1485 - iou_metric: 0.7116 - loss: 1.8072
# Epoch 11: val_dice_coefficient improved from 0.14366 to 0.15167, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.8160 - dice_coefficient: 0.1485 - iou_metric: 0.7116 - loss: 1.8072 - val_accuracy: 0.8429 - val_dice_coefficient: 0.1517 - val_iou_metric: 0.7344 - val_loss: 1.7582 - learning_rate: 1.0000e-04
# Epoch 12/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8190 - dice_coefficient: 0.1547 - iou_metric: 0.7165 - loss: 1.8055
# Epoch 12: val_dice_coefficient did not improve from 0.15167
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.8190 - dice_coefficient: 0.1547 - iou_metric: 0.7165 - loss: 1.8049 - val_accuracy: 0.5595 - val_dice_coefficient: 0.1276 - val_iou_metric: 0.3923 - val_loss: 1.9047 - learning_rate: 1.0000e-04
# Epoch 13/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8319 - dice_coefficient: 0.1591 - iou_metric: 0.7325 - loss: 1.7290
# Epoch 13: val_dice_coefficient improved from 0.15167 to 0.16212, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.8319 - dice_coefficient: 0.1591 - iou_metric: 0.7325 - loss: 1.7292 - val_accuracy: 0.8635 - val_dice_coefficient: 0.1621 - val_iou_metric: 0.7626 - val_loss: 1.6896 - learning_rate: 1.0000e-04
# Epoch 14/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8230 - dice_coefficient: 0.1659 - iou_metric: 0.7213 - loss: 1.7393
# Epoch 14: val_dice_coefficient did not improve from 0.16212
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8230 - dice_coefficient: 0.1659 - iou_metric: 0.7213 - loss: 1.7391 - val_accuracy: 0.7377 - val_dice_coefficient: 0.1528 - val_iou_metric: 0.5921 - val_loss: 1.7398 - learning_rate: 1.0000e-04
# Epoch 15/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8343 - dice_coefficient: 0.1692 - iou_metric: 0.7372 - loss: 1.6873
# Epoch 15: val_dice_coefficient did not improve from 0.16212
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.8343 - dice_coefficient: 0.1692 - iou_metric: 0.7372 - loss: 1.6873 - val_accuracy: 0.3879 - val_dice_coefficient: 0.1195 - val_iou_metric: 0.2450 - val_loss: 1.9564 - learning_rate: 1.0000e-04
# Epoch 16/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8387 - dice_coefficient: 0.1770 - iou_metric: 0.7424 - loss: 1.6779
# Epoch 16: val_dice_coefficient did not improve from 0.16212
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.8387 - dice_coefficient: 0.1769 - iou_metric: 0.7424 - loss: 1.6777 - val_accuracy: 0.5301 - val_dice_coefficient: 0.1359 - val_iou_metric: 0.3687 - val_loss: 1.8445 - learning_rate: 1.0000e-04
# Epoch 17/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8382 - dice_coefficient: 0.1805 - iou_metric: 0.7437 - loss: 1.6602
# Epoch 17: val_dice_coefficient improved from 0.16212 to 0.17624, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.8382 - dice_coefficient: 0.1804 - iou_metric: 0.7437 - loss: 1.6600 - val_accuracy: 0.8169 - val_dice_coefficient: 0.1762 - val_iou_metric: 0.6940 - val_loss: 1.5998 - learning_rate: 1.0000e-04
# Epoch 18/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8280 - dice_coefficient: 0.1849 - iou_metric: 0.7294 - loss: 1.6571
# Epoch 18: val_dice_coefficient improved from 0.17624 to 0.17686, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.8281 - dice_coefficient: 0.1849 - iou_metric: 0.7295 - loss: 1.6567 - val_accuracy: 0.7900 - val_dice_coefficient: 0.1769 - val_iou_metric: 0.6586 - val_loss: 1.5886 - learning_rate: 1.0000e-04
# Epoch 19/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8387 - dice_coefficient: 0.1905 - iou_metric: 0.7432 - loss: 1.5837
# Epoch 19: val_dice_coefficient did not improve from 0.17686
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.8387 - dice_coefficient: 0.1905 - iou_metric: 0.7432 - loss: 1.5837 - val_accuracy: 0.4806 - val_dice_coefficient: 0.1395 - val_iou_metric: 0.3257 - val_loss: 1.8115 - learning_rate: 1.0000e-04
# Epoch 20/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8448 - dice_coefficient: 0.1945 - iou_metric: 0.7504 - loss: 1.5614
# Epoch 20: val_dice_coefficient improved from 0.17686 to 0.18037, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.8447 - dice_coefficient: 0.1945 - iou_metric: 0.7503 - loss: 1.5614 - val_accuracy: 0.7858 - val_dice_coefficient: 0.1804 - val_iou_metric: 0.6512 - val_loss: 1.5688 - learning_rate: 1.0000e-04
# Epoch 21/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8327 - dice_coefficient: 0.1950 - iou_metric: 0.7375 - loss: 1.5613
# Epoch 21: val_dice_coefficient improved from 0.18037 to 0.18150, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.8327 - dice_coefficient: 0.1951 - iou_metric: 0.7375 - loss: 1.5611 - val_accuracy: 0.7389 - val_dice_coefficient: 0.1815 - val_iou_metric: 0.5962 - val_loss: 1.5615 - learning_rate: 1.0000e-04
# Epoch 22/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8469 - dice_coefficient: 0.2029 - iou_metric: 0.7575 - loss: 1.5231
# Epoch 22: val_dice_coefficient did not improve from 0.18150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.8467 - dice_coefficient: 0.2028 - iou_metric: 0.7574 - loss: 1.5232 - val_accuracy: 0.5909 - val_dice_coefficient: 0.1578 - val_iou_metric: 0.4315 - val_loss: 1.7060 - learning_rate: 1.0000e-04
# Epoch 23/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8500 - dice_coefficient: 0.2081 - iou_metric: 0.7605 - loss: 1.5023
# Epoch 23: val_dice_coefficient improved from 0.18150 to 0.18609, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.8498 - dice_coefficient: 0.2081 - iou_metric: 0.7603 - loss: 1.5024 - val_accuracy: 0.7394 - val_dice_coefficient: 0.1861 - val_iou_metric: 0.5978 - val_loss: 1.5370 - learning_rate: 1.0000e-04
# Epoch 24/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8481 - dice_coefficient: 0.2106 - iou_metric: 0.7576 - loss: 1.4948
# Epoch 24: val_dice_coefficient improved from 0.18609 to 0.20336, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.8481 - dice_coefficient: 0.2106 - iou_metric: 0.7576 - loss: 1.4947 - val_accuracy: 0.8273 - val_dice_coefficient: 0.2034 - val_iou_metric: 0.7082 - val_loss: 1.4467 - learning_rate: 1.0000e-04
# Epoch 25/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8539 - dice_coefficient: 0.2159 - iou_metric: 0.7655 - loss: 1.4700
# Epoch 25: val_dice_coefficient did not improve from 0.20336
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.8538 - dice_coefficient: 0.2159 - iou_metric: 0.7654 - loss: 1.4700 - val_accuracy: 0.3973 - val_dice_coefficient: 0.1414 - val_iou_metric: 0.2588 - val_loss: 1.7861 - learning_rate: 1.0000e-04
# Epoch 26/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8508 - dice_coefficient: 0.2198 - iou_metric: 0.7628 - loss: 1.4511
# Epoch 26: val_dice_coefficient improved from 0.20336 to 0.21571, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.8508 - dice_coefficient: 0.2198 - iou_metric: 0.7628 - loss: 1.4511 - val_accuracy: 0.8663 - val_dice_coefficient: 0.2157 - val_iou_metric: 0.7642 - val_loss: 1.4022 - learning_rate: 1.0000e-04
# Epoch 27/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8560 - dice_coefficient: 0.2231 - iou_metric: 0.7701 - loss: 1.4331
# Epoch 27: val_dice_coefficient did not improve from 0.21571
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.8558 - dice_coefficient: 0.2231 - iou_metric: 0.7698 - loss: 1.4333 - val_accuracy: 0.7447 - val_dice_coefficient: 0.1898 - val_iou_metric: 0.6032 - val_loss: 1.5343 - learning_rate: 1.0000e-04
# Epoch 28/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8442 - dice_coefficient: 0.2265 - iou_metric: 0.7548 - loss: 1.4600
# Epoch 28: val_dice_coefficient did not improve from 0.21571
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8442 - dice_coefficient: 0.2265 - iou_metric: 0.7549 - loss: 1.4598 - val_accuracy: 0.5022 - val_dice_coefficient: 0.1500 - val_iou_metric: 0.3492 - val_loss: 1.7766 - learning_rate: 1.0000e-04
# Epoch 29/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8519 - dice_coefficient: 0.2291 - iou_metric: 0.7640 - loss: 1.4204
# Epoch 29: val_dice_coefficient did not improve from 0.21571
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8519 - dice_coefficient: 0.2291 - iou_metric: 0.7640 - loss: 1.4204 - val_accuracy: 0.6420 - val_dice_coefficient: 0.1743 - val_iou_metric: 0.4848 - val_loss: 1.6208 - learning_rate: 1.0000e-04
# Epoch 30/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8539 - dice_coefficient: 0.2341 - iou_metric: 0.7662 - loss: 1.3983
# Epoch 30: val_dice_coefficient improved from 0.21571 to 0.23016, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.8539 - dice_coefficient: 0.2341 - iou_metric: 0.7661 - loss: 1.3985 - val_accuracy: 0.8636 - val_dice_coefficient: 0.2302 - val_iou_metric: 0.7599 - val_loss: 1.3368 - learning_rate: 1.0000e-04
# Epoch 31/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8504 - dice_coefficient: 0.2346 - iou_metric: 0.7618 - loss: 1.4051
# Epoch 31: val_dice_coefficient improved from 0.23016 to 0.23522, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.8504 - dice_coefficient: 0.2346 - iou_metric: 0.7618 - loss: 1.4050 - val_accuracy: 0.8815 - val_dice_coefficient: 0.2352 - val_iou_metric: 0.7870 - val_loss: 1.3303 - learning_rate: 1.0000e-04
# Epoch 32/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8585 - dice_coefficient: 0.2414 - iou_metric: 0.7713 - loss: 1.3754
# Epoch 32: val_dice_coefficient improved from 0.23522 to 0.23765, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.8584 - dice_coefficient: 0.2413 - iou_metric: 0.7712 - loss: 1.3755 - val_accuracy: 0.8739 - val_dice_coefficient: 0.2376 - val_iou_metric: 0.7748 - val_loss: 1.3124 - learning_rate: 1.0000e-04
# Epoch 33/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8506 - dice_coefficient: 0.2431 - iou_metric: 0.7624 - loss: 1.3877
# Epoch 33: val_dice_coefficient did not improve from 0.23765
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.8506 - dice_coefficient: 0.2430 - iou_metric: 0.7624 - loss: 1.3874 - val_accuracy: 0.8111 - val_dice_coefficient: 0.2250 - val_iou_metric: 0.6868 - val_loss: 1.3610 - learning_rate: 1.0000e-04
# Epoch 34/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8648 - dice_coefficient: 0.2456 - iou_metric: 0.7805 - loss: 1.3412
# Epoch 34: val_dice_coefficient did not improve from 0.23765
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8648 - dice_coefficient: 0.2457 - iou_metric: 0.7804 - loss: 1.3413 - val_accuracy: 0.8368 - val_dice_coefficient: 0.2277 - val_iou_metric: 0.7209 - val_loss: 1.3583 - learning_rate: 1.0000e-04
# Epoch 35/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8567 - dice_coefficient: 0.2506 - iou_metric: 0.7691 - loss: 1.3609
# Epoch 35: val_dice_coefficient improved from 0.23765 to 0.24513, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.8568 - dice_coefficient: 0.2505 - iou_metric: 0.7692 - loss: 1.3607 - val_accuracy: 0.8690 - val_dice_coefficient: 0.2451 - val_iou_metric: 0.7672 - val_loss: 1.2849 - learning_rate: 1.0000e-04
# Epoch 36/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8580 - dice_coefficient: 0.2539 - iou_metric: 0.7712 - loss: 1.3682
# Epoch 36: val_dice_coefficient did not improve from 0.24513
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.8579 - dice_coefficient: 0.2538 - iou_metric: 0.7710 - loss: 1.3679 - val_accuracy: 0.8529 - val_dice_coefficient: 0.2424 - val_iou_metric: 0.7431 - val_loss: 1.2927 - learning_rate: 1.0000e-04
# Epoch 37/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8603 - dice_coefficient: 0.2542 - iou_metric: 0.7739 - loss: 1.3372
# Epoch 37: val_dice_coefficient improved from 0.24513 to 0.25262, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - accuracy: 0.8602 - dice_coefficient: 0.2542 - iou_metric: 0.7738 - loss: 1.3374 - val_accuracy: 0.8824 - val_dice_coefficient: 0.2526 - val_iou_metric: 0.7875 - val_loss: 1.2685 - learning_rate: 1.0000e-04
# Epoch 38/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8602 - dice_coefficient: 0.2601 - iou_metric: 0.7730 - loss: 1.3327
# Epoch 38: val_dice_coefficient did not improve from 0.25262
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8602 - dice_coefficient: 0.2601 - iou_metric: 0.7730 - loss: 1.3327 - val_accuracy: 0.8398 - val_dice_coefficient: 0.2402 - val_iou_metric: 0.7248 - val_loss: 1.3066 - learning_rate: 1.0000e-04
# Epoch 39/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8624 - dice_coefficient: 0.2610 - iou_metric: 0.7761 - loss: 1.3338
# Epoch 39: val_dice_coefficient did not improve from 0.25262
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8624 - dice_coefficient: 0.2610 - iou_metric: 0.7761 - loss: 1.3336 - val_accuracy: 0.6232 - val_dice_coefficient: 0.1875 - val_iou_metric: 0.4709 - val_loss: 1.5566 - learning_rate: 1.0000e-04
# Epoch 40/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8673 - dice_coefficient: 0.2637 - iou_metric: 0.7834 - loss: 1.3085
# Epoch 40: val_dice_coefficient improved from 0.25262 to 0.25615, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.8673 - dice_coefficient: 0.2637 - iou_metric: 0.7833 - loss: 1.3086 - val_accuracy: 0.8748 - val_dice_coefficient: 0.2562 - val_iou_metric: 0.7763 - val_loss: 1.2567 - learning_rate: 1.0000e-04
# Epoch 41/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8638 - dice_coefficient: 0.2627 - iou_metric: 0.7782 - loss: 1.2940
# Epoch 41: val_dice_coefficient did not improve from 0.25615
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8638 - dice_coefficient: 0.2628 - iou_metric: 0.7782 - loss: 1.2941 - val_accuracy: 0.7175 - val_dice_coefficient: 0.2067 - val_iou_metric: 0.5747 - val_loss: 1.4727 - learning_rate: 1.0000e-04
# Epoch 42/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8671 - dice_coefficient: 0.2706 - iou_metric: 0.7823 - loss: 1.3053
# Epoch 42: val_dice_coefficient did not improve from 0.25615
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8671 - dice_coefficient: 0.2705 - iou_metric: 0.7822 - loss: 1.3053 - val_accuracy: 0.8295 - val_dice_coefficient: 0.2434 - val_iou_metric: 0.7100 - val_loss: 1.2987 - learning_rate: 1.0000e-04
# Epoch 43/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8653 - dice_coefficient: 0.2693 - iou_metric: 0.7809 - loss: 1.2971
# Epoch 43: val_dice_coefficient did not improve from 0.25615
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.8653 - dice_coefficient: 0.2693 - iou_metric: 0.7809 - loss: 1.2971 - val_accuracy: 0.7799 - val_dice_coefficient: 0.2291 - val_iou_metric: 0.6467 - val_loss: 1.3634 - learning_rate: 1.0000e-04
# Epoch 44/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8641 - dice_coefficient: 0.2735 - iou_metric: 0.7770 - loss: 1.2974
# Epoch 44: val_dice_coefficient did not improve from 0.25615
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8641 - dice_coefficient: 0.2734 - iou_metric: 0.7771 - loss: 1.2974 - val_accuracy: 0.7125 - val_dice_coefficient: 0.2114 - val_iou_metric: 0.5647 - val_loss: 1.4389 - learning_rate: 1.0000e-04
# Epoch 45/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8643 - dice_coefficient: 0.2776 - iou_metric: 0.7800 - loss: 1.2856
# Epoch 45: val_dice_coefficient did not improve from 0.25615
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8644 - dice_coefficient: 0.2776 - iou_metric: 0.7800 - loss: 1.2853 - val_accuracy: 0.8389 - val_dice_coefficient: 0.2520 - val_iou_metric: 0.7240 - val_loss: 1.2648 - learning_rate: 1.0000e-04
# Epoch 46/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8633 - dice_coefficient: 0.2729 - iou_metric: 0.7774 - loss: 1.2872
# Epoch 46: val_dice_coefficient improved from 0.25615 to 0.27182, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.8633 - dice_coefficient: 0.2729 - iou_metric: 0.7775 - loss: 1.2872 - val_accuracy: 0.8891 - val_dice_coefficient: 0.2718 - val_iou_metric: 0.7982 - val_loss: 1.2200 - learning_rate: 1.0000e-04
# Epoch 47/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8618 - dice_coefficient: 0.2783 - iou_metric: 0.7772 - loss: 1.2856
# Epoch 47: val_dice_coefficient did not improve from 0.27182
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8618 - dice_coefficient: 0.2783 - iou_metric: 0.7772 - loss: 1.2856 - val_accuracy: 0.8630 - val_dice_coefficient: 0.2641 - val_iou_metric: 0.7580 - val_loss: 1.2259 - learning_rate: 1.0000e-04
# Epoch 48/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8636 - dice_coefficient: 0.2763 - iou_metric: 0.7781 - loss: 1.2645
# Epoch 48: val_dice_coefficient did not improve from 0.27182
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8636 - dice_coefficient: 0.2763 - iou_metric: 0.7781 - loss: 1.2646 - val_accuracy: 0.8603 - val_dice_coefficient: 0.2642 - val_iou_metric: 0.7537 - val_loss: 1.2189 - learning_rate: 1.0000e-04
# Epoch 49/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8698 - dice_coefficient: 0.2862 - iou_metric: 0.7866 - loss: 1.2567
# Epoch 49: val_dice_coefficient did not improve from 0.27182
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.8698 - dice_coefficient: 0.2861 - iou_metric: 0.7865 - loss: 1.2568 - val_accuracy: 0.6873 - val_dice_coefficient: 0.2104 - val_iou_metric: 0.5319 - val_loss: 1.4586 - learning_rate: 1.0000e-04
# Epoch 50/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8691 - dice_coefficient: 0.2851 - iou_metric: 0.7841 - loss: 1.2614
# Epoch 50: val_dice_coefficient improved from 0.27182 to 0.28080, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.8691 - dice_coefficient: 0.2850 - iou_metric: 0.7842 - loss: 1.2613 - val_accuracy: 0.8947 - val_dice_coefficient: 0.2808 - val_iou_metric: 0.8074 - val_loss: 1.1968 - learning_rate: 1.0000e-04
# Visualizando predicciones...
# Visualizing 4 samples from the validation set...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step
# ¡Entrenamiento completado! El mejor modelo se guardó como 'best_weed_model.h5'
# Evaluando el modelo final en el conjunto de validación:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9024 - dice_coefficient: 0.2887 - iou_metric: 0.8292 - loss: 1.1785
# Validation Loss: 1.1968
# Validation Dice Coefficient: 0.2808
# Validation IoU: 0.8074
# Validation Accuracy: 0.8947
# IoU for Background: 0.9146
# IoU for Cow-tongue: 0.1226
# IoU for Dandelion: 0.7188
# IoU for Kikuyo: 0.7054
# IoU for Other: 0.6384
# IoU for Potato: 0.2908
