# %% [markdown]
# <a href="https://colab.research.google.com/github/Masciel-Sevilla/CalculadoraVLSM_MascielSevilla/blob/master/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, regularizers
import numpy as np
import matplotlib.pyplot as plt
import os
from glob import glob

# --- Configuración del modelo ---
IMG_HEIGHT = 128
IMG_WIDTH = 128
NUM_CLASSES = 6  # 0-background, 1-Cow-tongue, 2-Dandelion, 3-Kikuyo, 4-Other, 5-Potato
BATCH_SIZE = 16
EPOCHS = 50
LEARNING_RATE = 1e-4

# --- Paths ---
BASE_PATH = '/content/Balanced'
TRAIN_IMAGES_PATH = os.path.join(BASE_PATH, 'train/images')
TRAIN_MASKS_PATH = os.path.join(BASE_PATH, 'train/masks')
VAL_IMAGES_PATH = os.path.join(BASE_PATH, 'val/images')
VAL_MASKS_PATH = os.path.join(BASE_PATH, 'val/masks')

# --- Módulos del modelo ---
class ASPPModule(layers.Layer):
    def __init__(self, filters=64, **kwargs):
        super(ASPPModule, self).__init__(**kwargs)
        self.filters = filters

        self.conv_1x1 = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1 = layers.BatchNormalization()
        self.relu_1x1 = layers.ReLU()

        self.conv_3x3_6 = layers.Conv2D(filters, 3, padding='same', dilation_rate=6, use_bias=False)
        self.bn_3x3_6 = layers.BatchNormalization()
        self.relu_3x3_6 = layers.ReLU()

        self.conv_3x3_12 = layers.Conv2D(filters, 3, padding='same', dilation_rate=12, use_bias=False)
        self.bn_3x3_12 = layers.BatchNormalization()
        self.relu_3x3_12 = layers.ReLU()

        self.global_avg_pool = layers.GlobalAveragePooling2D(keepdims=True)
        self.conv_1x1_gap = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1_gap = layers.BatchNormalization()
        self.relu_1x1_gap = layers.ReLU()

        self.conv_final = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_final = layers.BatchNormalization()
        self.relu_final = layers.ReLU()
        # FIX: Instantiate Dropout once in __init__
        self.dropout = layers.Dropout(0.3)

    def call(self, inputs, training=None):
        input_shape = tf.shape(inputs) # This is fine as it's a tf.Tensor shape

        conv_1x1 = self.relu_1x1(self.bn_1x1(self.conv_1x1(inputs), training=training))
        conv_3x3_6 = self.relu_3x3_6(self.bn_3x3_6(self.conv_3x3_6(inputs), training=training))
        conv_3x3_12 = self.relu_3x3_12(self.bn_3x3_12(self.conv_3x3_12(inputs), training=training))

        gap = self.global_avg_pool(inputs)
        gap = self.relu_1x1_gap(self.bn_1x1_gap(self.conv_1x1_gap(gap), training=training))
        # This tf.image.resize is fine because it's operating on a KerasTensor directly
        # and doesn't create new variables internally per call.
        gap = tf.image.resize(gap, [input_shape[1], input_shape[2]], method='bilinear')

        concat = layers.Concatenate()([conv_1x1, conv_3x3_6, conv_3x3_12, gap])

        output = self.relu_final(self.bn_final(self.conv_final(concat), training=training))
        # FIX: Call the instantiated dropout layer
        output = self.dropout(output, training=training)

        return output

class DeformableAttention(layers.Layer):
    def __init__(self, filters, **kwargs):
        super(DeformableAttention, self).__init__(**kwargs)
        self.filters = filters

        # FIX: Instantiate Dropout here if you add it to this layer later
        # self.dropout = layers.Dropout(0.3) # Example if you needed it here

    def build(self, input_shape):
        self.attention_conv = layers.Conv2D(self.filters, 1, padding='same', activation='sigmoid', name='attention_weights_conv', use_bias=False)
        self.bn_attention = layers.BatchNormalization()

        self.feature_conv = layers.Conv2D(self.filters, 3, padding='same', name='feature_processing_conv', use_bias=False)
        self.bn_feature = layers.BatchNormalization()
        self.relu_feature = layers.ReLU()

        super(DeformableAttention, self).build(input_shape)

    def call(self, inputs, training=None):
        attention_weights = self.bn_attention(self.attention_conv(inputs), training=training)
        features = self.relu_feature(self.bn_feature(self.feature_conv(inputs), training=training))
        attended_features = features * attention_weights
        return attended_features

def create_efficient_backbone(input_shape):
    base_model = tf.keras.applications.EfficientNetV2B0( # You can change this to B1, B2, etc.
        input_shape=input_shape,
        weights='imagenet',
        include_top=False
    )
    base_model.trainable = False

    layer_names = [
        'block1a_project_activation',
        'block2a_expand_activation',
        'block3a_expand_activation',
        'block4a_expand_activation',
        'top_activation'
    ]

    outputs = [base_model.get_layer(name).output for name in layer_names]

    return Model(inputs=base_model.input, outputs=outputs, name='EfficientNetV2B0_Backbone')

def create_weed_detection_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=NUM_CLASSES):
    inputs = layers.Input(shape=input_shape)

    backbone = create_efficient_backbone(input_shape)
    backbone_features = backbone(inputs)

    deep_features = backbone_features[-1]
    mid_features = backbone_features[-3]

    aspp_features = ASPPModule(filters=64)(deep_features)
    attended_features = DeformableAttention(filters=64)(aspp_features)

    # Decoder Path: Use layers.ReLU() explicitly after BatchNormalization
    decoder_features = layers.Conv2DTranspose(64, 2, strides=2, padding='same', use_bias=False)(attended_features)
    decoder_features = layers.BatchNormalization()(decoder_features)
    decoder_features = layers.ReLU()(decoder_features)
    # FIX: Instantiate Dropout before use, or apply it directly if it's a one-off
    # For layers outside custom classes, applying directly is fine if not creating variables per call in a loop.
    # However, it's generally safer to instantiate if you're unsure or use it multiple times.
    # Here, for simplicity and consistency with the fix, we will instantiate it.
    decoder_dropout1 = layers.Dropout(0.3)
    decoder_features = decoder_dropout1(decoder_features)


    decoder_features = layers.Conv2DTranspose(64, 2, strides=2, padding='same', use_bias=False)(decoder_features)
    decoder_features = layers.BatchNormalization()(decoder_features)
    decoder_features = layers.ReLU()(decoder_features)

    mid_processed = layers.Conv2D(32, 1, padding='same', use_bias=False)(mid_features)
    mid_processed = layers.BatchNormalization()(mid_processed)
    mid_processed = layers.ReLU()(mid_processed)

    decoder_concat = layers.Concatenate()([decoder_features, mid_processed])

    decoder_conv1 = layers.Conv2D(64, 3, padding='same', use_bias=False)(decoder_concat)
    decoder_conv1 = layers.BatchNormalization()(decoder_conv1)
    decoder_conv1 = layers.ReLU()(decoder_conv1)
    # FIX: Instantiate Dropout before use
    decoder_dropout2 = layers.Dropout(0.3)
    decoder_conv1 = decoder_dropout2(decoder_conv1)

    decoder_conv2 = layers.Conv2D(64, 3, padding='same', use_bias=False)(decoder_conv1)
    decoder_conv2 = layers.BatchNormalization()(decoder_conv2)
    decoder_conv2 = layers.ReLU()(decoder_conv2)

    final_upsample = layers.Conv2DTranspose(NUM_CLASSES, 2, strides=2, padding='same', use_bias=False)(decoder_conv2)
    final_upsample = layers.BatchNormalization()(final_upsample)
    final_upsample = layers.ReLU()(final_upsample)

    final_upsample = layers.Conv2DTranspose(NUM_CLASSES, 2, strides=2, padding='same', use_bias=False)(final_upsample)
    final_upsample = layers.BatchNormalization()(final_upsample)
    final_upsample = layers.ReLU()(final_upsample)

    final_upsample = layers.Conv2DTranspose(NUM_CLASSES, 2, strides=2, padding='same', use_bias=False)(final_upsample)
    final_upsample = layers.BatchNormalization()(final_upsample)
    final_upsample = layers.ReLU()(final_upsample)

    outputs = layers.Conv2D(num_classes, 1, padding='same', activation='softmax', name='segmentation_output')(final_upsample)

    model = Model(inputs=inputs, outputs=outputs, name='WeedDetectionModel')

    return model

# --- Métricas y Funciones de Pérdida (Resto del código permanece igual) ---
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(tf.cast(y_true, tf.float32), [-1, NUM_CLASSES])
    y_pred_f = tf.reshape(tf.cast(y_pred, tf.float32), [-1, NUM_CLASSES])

    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
    dice_scores = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f, axis=0) + tf.reduce_sum(y_pred_f, axis=0) + smooth)

    return tf.reduce_mean(dice_scores)

def weighted_categorical_crossentropy(weights):
    def loss(y_true, y_pred):
        y_pred /= tf.reduce_sum(y_pred, axis=-1, keepdims=True)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        loss = y_true * tf.math.log(y_pred) * weights
        return -tf.reduce_sum(loss, axis=-1)

    return loss

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    class_weights = tf.constant([0.5, 2.5, 2.5, 1.0, 1.0, 2.5])
    ce_loss = weighted_categorical_crossentropy(class_weights)(y_true, y_pred)
    d_loss = dice_loss(y_true, y_pred)
    return ce_loss + (1.0 * d_loss)

def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3]) - intersection

    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou)

def iou_per_class(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2])
    union = tf.reduce_sum(y_true, axis=[1, 2]) + tf.reduce_sum(y_pred, axis=[1, 2]) - intersection

    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou, axis=0)

# --- Carga y Preprocesamiento de Datos (Resto del código permanece igual) ---
def load_and_preprocess_data(images_path, masks_path):
    def load_image(image_path):
        image = tf.io.read_file(image_path)
        image = tf.image.decode_image(image, channels=3, expand_animations=False)
        image.set_shape([None, None, 3])
        image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH], method='bilinear')
        image = tf.cast(image, tf.float32) / 255.0
        return image

    def load_mask(mask_path):
        mask = tf.io.read_file(mask_path)
        mask = tf.image.decode_png(mask, channels=1)
        mask = tf.image.resize(mask, [IMG_HEIGHT, IMG_WIDTH], method='nearest')
        mask = tf.cast(mask, tf.int32)
        mask = tf.squeeze(mask, axis=-1)
        mask = tf.one_hot(mask, NUM_CLASSES)
        return mask

    image_paths = sorted(glob(os.path.join(images_path, '*.jpg')))
    mask_paths = sorted(glob(os.path.join(masks_path, '*.png')))

    if not image_paths:
        raise FileNotFoundError(f"No image files found in: {images_path}. Check path and file extensions.")
    if not mask_paths:
        raise FileNotFoundError(f"No mask files found in: {masks_path}. Check path and file extensions.")

    image_names = [os.path.basename(p).split('.')[0] for p in image_paths]
    mask_names = [os.path.basename(p).split('.')[0] for p in mask_paths]

    if set(image_names) != set(mask_names):
        print("Warning: Image and mask filenames do not match exactly. This might lead to misaligned data.")

    if len(image_paths) != len(mask_paths):
        print(f"DEBUG: Found {len(image_paths)} images and {len(mask_paths)} masks.")
        print("DEBUG: First 5 image files:", [os.path.basename(p) for p in image_paths[:5]])
        print("DEBUG: First 5 mask files:", [os.path.basename(p) for p in mask_paths[:5]])

    print(f"Found {len(image_paths)} images and {len(mask_paths)} masks")

    image_ds = tf.data.Dataset.from_tensor_slices(image_paths).map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
    mask_ds = tf.data.Dataset.from_tensor_slices(mask_paths).map(load_mask, num_parallel_calls=tf.data.AUTOTUNE)

    dataset = tf.data.Dataset.zip((image_ds, mask_ds))

    return dataset

def augment_data(image, mask):
    if tf.random.uniform([]) > 0.5:
        image = tf.image.flip_left_right(image)
        mask = tf.image.flip_left_right(mask)

    if tf.random.uniform([]) > 0.5:
        image = tf.image.flip_up_down(image)
        mask = tf.image.flip_up_down(mask)

    if tf.random.uniform([]) > 0.5:
        k = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        image = tf.image.rot90(image, k)
        mask = tf.image.rot90(mask, k)

    image = tf.image.random_brightness(image, max_delta=0.3)
    image = tf.image.random_contrast(image, lower=0.7, upper=1.3)
    image = tf.image.random_hue(image, max_delta=0.1)
    image = tf.image.random_saturation(image, lower=0.7, upper=1.3)

    image = tf.clip_by_value(image, 0.0, 1.0)

    return image, mask

def create_datasets():
    train_dataset = load_and_preprocess_data(TRAIN_IMAGES_PATH, TRAIN_MASKS_PATH)
    val_dataset = load_and_preprocess_data(VAL_IMAGES_PATH, VAL_MASKS_PATH)

    train_dataset = train_dataset.cache()
    val_dataset = val_dataset.cache()

    train_dataset = train_dataset.shuffle(buffer_size=1000).map(augment_data, num_parallel_calls=tf.data.AUTOTUNE)
    train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    val_dataset = val_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    return train_dataset, val_dataset

def train_model(train_dataset, val_dataset, model_save_path='best_weed_model.h5'):
    model = create_weed_detection_model()
    model.summary()

    optimizer = tf.keras.optimizers.AdamW(learning_rate=LEARNING_RATE, weight_decay=1e-4)

    model.compile(
        optimizer=optimizer,
        loss=combined_loss,
        metrics=[dice_coefficient, iou_metric, 'accuracy']
    )

    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(
            model_save_path,
            monitor='val_dice_coefficient',
            save_best_only=True,
            mode='max',
            verbose=1
        ),
        tf.keras.callbacks.EarlyStopping(
            monitor='val_dice_coefficient',
            patience=30,
            mode='max',
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=15,
            min_lr=1e-8,
            verbose=1
        ),
    ]

    print(f"Starting training for {EPOCHS} epochs...")
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=val_dataset,
        callbacks=callbacks,
        verbose=1
    )

    return model, history

def visualize_predictions(model, val_dataset, num_samples=4):
    class_names = ['Background', 'Cow-tongue', 'Dandelion', 'Kikuyo', 'Other', 'Potato']

    print(f"Visualizing {num_samples} samples from the validation set...")

    for images, masks in val_dataset.take(1):
        predictions = model.predict(images)

        fig, axes = plt.subplots(num_samples, 3, figsize=(15, 5 * num_samples))

        for i in range(min(num_samples, images.shape[0])):
            axes[i, 0].imshow(images[i])
            axes[i, 0].set_title('Original Image')
            axes[i, 0].axis('off')

            true_mask = np.argmax(masks[i].numpy(), axis=-1)
            axes[i, 1].imshow(true_mask, cmap='tab10', vmin=0, vmax=NUM_CLASSES - 1)
            axes[i, 1].set_title('True Mask')
            axes[i, 1].axis('off')

            pred_mask = np.argmax(predictions[i], axis=-1)
            axes[i, 2].imshow(pred_mask, cmap='tab10', vmin=0, vmax=NUM_CLASSES - 1)
            axes[i, 2].set_title('Predicted Mask')
            axes[i, 2].axis('off')

        plt.tight_layout()
        plt.show()
        break

if __name__ == "__main__":
    if not os.path.exists(TRAIN_IMAGES_PATH):
        print(f"Error: La ruta de imágenes de entrenamiento NO existe: {TRAIN_IMAGES_PATH}")
        exit()
    if not os.path.exists(TRAIN_MASKS_PATH):
        print(f"Error: La ruta de máscaras de entrenamiento NO existe: {TRAIN_MASKS_PATH}")
        exit()
    if not os.path.exists(VAL_IMAGES_PATH):
        print(f"Error: La ruta de imágenes de validación NO existe: {VAL_IMAGES_PATH}")
        exit()
    if not os.path.exists(VAL_MASKS_PATH):
        print(f"Error: La ruta de máscaras de validación NO existe: {VAL_MASKS_PATH}")
        exit()

    print("Creando datasets...")
    train_ds, val_ds = create_datasets()

    print("Entrenando modelo...")
    model, history = train_model(train_ds, val_ds)

    print("Visualizando predicciones...")
    visualize_predictions(model, val_ds)

    print("¡Entrenamiento completado! El mejor modelo se guardó como 'best_weed_model.h5'")

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['dice_coefficient'], label='Dice Coeff (Train)')
    plt.plot(history.history['val_dice_coefficient'], label='Dice Coeff (Validation)')
    plt.title('Dice Coefficient over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Dice Coefficient')
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Loss (Train)')
    plt.plot(history.history['val_loss'], label='Loss (Validation)')
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.show()

    print("\nEvaluando el modelo final en el conjunto de validación:")
    final_metrics = model.evaluate(val_ds)
    print(f"Validation Loss: {final_metrics[0]:.4f}")
    print(f"Validation Dice Coefficient: {final_metrics[1]:.4f}")
    print(f"Validation IoU: {final_metrics[2]:.4f}")
    print(f"Validation Accuracy: {final_metrics[3]:.4f}")

    iou_per_class_values = []
    for images, masks in val_ds.take(len(list(val_ds))):
        predictions = model.predict(images, verbose=0)
        iou_per_class_values.append(iou_per_class(masks, predictions))

    iou_per_class_values = tf.reduce_mean(tf.stack(iou_per_class_values), axis=0).numpy()

    class_names = ['Background', 'Cow-tongue', 'Dandelion', 'Kikuyo', 'Other', 'Potato']
    for i, iou in enumerate(iou_per_class_values):
        print(f"IoU for {class_names[i]}: {iou:.4f}")
# Out:
# Creando datasets...
# Found 1680 images and 1680 masks
# Found 210 images and 210 masks
# Entrenando modelo...
# Model: "WeedDetectionModel"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ EfficientNetV2B0_B… │ [(None, 64, 64,   │  5,919,312 │ input_layer_6[0]… │
# │ (Functional)        │ 16), (None, 32,   │            │                   │
# │                     │ 32, 64), (None,   │            │                   │
# │                     │ 16, 16, 128),     │            │                   │
# │                     │ (None, 16, 16,    │            │                   │
# │                     │ 192), (None, 4,   │            │                   │
# │                     │ 4, 1280)]         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aspp_module_3       │ (None, 4, 4, 64)  │  1,656,064 │ EfficientNetV2B0… │
# │ (ASPPModule)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deformable_attenti… │ (None, 4, 4, 64)  │     41,472 │ aspp_module_3[0]… │
# │ (DeformableAttenti… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_7  │ (None, 8, 8, 64)  │     16,384 │ deformable_atten… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_20 (ReLU)     │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 8, 8, 64)  │          0 │ re_lu_20[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_8  │ (None, 16, 16,    │     16,384 │ dropout_11[0][0]  │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 16, 16,    │      4,096 │ EfficientNetV2B0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_21 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_22 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 16, 16,    │          0 │ re_lu_21[0][0],   │
# │ (Concatenate)       │ 96)               │            │ re_lu_22[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 16, 16,    │     55,296 │ concatenate_11[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_23 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 16, 16,    │          0 │ re_lu_23[0][0]    │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 16, 16,    │     36,864 │ dropout_12[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_24 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_9  │ (None, 32, 32, 6) │      1,536 │ re_lu_24[0][0]    │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32, 6) │         24 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_25 (ReLU)     │ (None, 32, 32, 6) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_10 │ (None, 64, 64, 6) │        144 │ re_lu_25[0][0]    │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64, 6) │         24 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_26 (ReLU)     │ (None, 64, 64, 6) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_11 │ (None, 128, 128,  │        144 │ re_lu_26[0][0]    │
# │ (Conv2DTranspose)   │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         24 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_27 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segmentation_output │ (None, 128, 128,  │         42 │ re_lu_27[0][0]    │
# │ (Conv2D)            │ 6)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,748,962 (29.56 MB)
#  Trainable params: 1,828,142 (6.97 MB)
#  Non-trainable params: 5,920,820 (22.59 MB)
# Starting training for 50 epochs...
# Epoch 1/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.2341 - dice_coefficient: 0.0921 - iou_metric: 0.1334 - loss: 2.4486
# Epoch 1: val_dice_coefficient improved from -inf to 0.08783, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 63s 165ms/step - accuracy: 0.2347 - dice_coefficient: 0.0921 - iou_metric: 0.1338 - loss: 2.4466 - val_accuracy: 0.4661 - val_dice_coefficient: 0.0878 - val_iou_metric: 0.3087 - val_loss: 2.3209 - learning_rate: 1.0000e-04
# Epoch 2/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3219 - dice_coefficient: 0.0933 - iou_metric: 0.1931 - loss: 2.3053
# Epoch 2: val_dice_coefficient improved from 0.08783 to 0.09098, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 44s 36ms/step - accuracy: 0.3226 - dice_coefficient: 0.0934 - iou_metric: 0.1936 - loss: 2.3051 - val_accuracy: 0.5505 - val_dice_coefficient: 0.0910 - val_iou_metric: 0.3871 - val_loss: 2.2893 - learning_rate: 1.0000e-04
# Epoch 3/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4068 - dice_coefficient: 0.1010 - iou_metric: 0.2568 - loss: 2.2311
# Epoch 3: val_dice_coefficient did not improve from 0.09098
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.4071 - dice_coefficient: 0.1011 - iou_metric: 0.2571 - loss: 2.2309 - val_accuracy: 0.2784 - val_dice_coefficient: 0.0901 - val_iou_metric: 0.1609 - val_loss: 2.3142 - learning_rate: 1.0000e-04
# Epoch 4/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4511 - dice_coefficient: 0.1134 - iou_metric: 0.2930 - loss: 2.1467
# Epoch 4: val_dice_coefficient did not improve from 0.09098
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.4513 - dice_coefficient: 0.1134 - iou_metric: 0.2932 - loss: 2.1462 - val_accuracy: 0.3044 - val_dice_coefficient: 0.0846 - val_iou_metric: 0.1785 - val_loss: 2.6224 - learning_rate: 1.0000e-04
# Epoch 5/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4997 - dice_coefficient: 0.1237 - iou_metric: 0.3355 - loss: 2.0498
# Epoch 5: val_dice_coefficient did not improve from 0.09098
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.4998 - dice_coefficient: 0.1238 - iou_metric: 0.3356 - loss: 2.0499 - val_accuracy: 0.3300 - val_dice_coefficient: 0.0846 - val_iou_metric: 0.1963 - val_loss: 2.5088 - learning_rate: 1.0000e-04
# Epoch 6/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5708 - dice_coefficient: 0.1369 - iou_metric: 0.4037 - loss: 2.0081
# Epoch 6: val_dice_coefficient did not improve from 0.09098
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.5711 - dice_coefficient: 0.1369 - iou_metric: 0.4041 - loss: 2.0080 - val_accuracy: 0.2933 - val_dice_coefficient: 0.0846 - val_iou_metric: 0.1711 - val_loss: 2.4454 - learning_rate: 1.0000e-04
# Epoch 7/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6880 - dice_coefficient: 0.1447 - iou_metric: 0.5348 - loss: 1.9573
# Epoch 7: val_dice_coefficient improved from 0.09098 to 0.10255, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.6881 - dice_coefficient: 0.1447 - iou_metric: 0.5350 - loss: 1.9571 - val_accuracy: 0.3729 - val_dice_coefficient: 0.1026 - val_iou_metric: 0.2303 - val_loss: 2.1493 - learning_rate: 1.0000e-04
# Epoch 8/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7915 - dice_coefficient: 0.1497 - iou_metric: 0.6799 - loss: 1.9104
# Epoch 8: val_dice_coefficient improved from 0.10255 to 0.15416, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.7915 - dice_coefficient: 0.1497 - iou_metric: 0.6799 - loss: 1.9103 - val_accuracy: 0.8487 - val_dice_coefficient: 0.1542 - val_iou_metric: 0.7410 - val_loss: 1.8020 - learning_rate: 1.0000e-04
# Epoch 9/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8110 - dice_coefficient: 0.1607 - iou_metric: 0.7071 - loss: 1.8775
# Epoch 9: val_dice_coefficient did not improve from 0.15416
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.8110 - dice_coefficient: 0.1606 - iou_metric: 0.7072 - loss: 1.8770 - val_accuracy: 0.7556 - val_dice_coefficient: 0.1499 - val_iou_metric: 0.6148 - val_loss: 1.8165 - learning_rate: 1.0000e-04
# Epoch 10/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8171 - dice_coefficient: 0.1626 - iou_metric: 0.7164 - loss: 1.8136
# Epoch 10: val_dice_coefficient improved from 0.15416 to 0.16395, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.8172 - dice_coefficient: 0.1627 - iou_metric: 0.7164 - loss: 1.8135 - val_accuracy: 0.8808 - val_dice_coefficient: 0.1639 - val_iou_metric: 0.7902 - val_loss: 1.7493 - learning_rate: 1.0000e-04
# Epoch 11/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8265 - dice_coefficient: 0.1723 - iou_metric: 0.7265 - loss: 1.7773
# Epoch 11: val_dice_coefficient improved from 0.16395 to 0.16876, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.8266 - dice_coefficient: 0.1723 - iou_metric: 0.7266 - loss: 1.7769 - val_accuracy: 0.8226 - val_dice_coefficient: 0.1688 - val_iou_metric: 0.7046 - val_loss: 1.6985 - learning_rate: 1.0000e-04
# Epoch 12/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8325 - dice_coefficient: 0.1767 - iou_metric: 0.7357 - loss: 1.7395
# Epoch 12: val_dice_coefficient did not improve from 0.16876
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.8324 - dice_coefficient: 0.1767 - iou_metric: 0.7356 - loss: 1.7396 - val_accuracy: 0.7818 - val_dice_coefficient: 0.1594 - val_iou_metric: 0.6519 - val_loss: 1.7378 - learning_rate: 1.0000e-04
# Epoch 13/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8297 - dice_coefficient: 0.1793 - iou_metric: 0.7330 - loss: 1.7199
# Epoch 13: val_dice_coefficient improved from 0.16876 to 0.17142, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.8296 - dice_coefficient: 0.1793 - iou_metric: 0.7329 - loss: 1.7200 - val_accuracy: 0.8212 - val_dice_coefficient: 0.1714 - val_iou_metric: 0.7008 - val_loss: 1.6732 - learning_rate: 1.0000e-04
# Epoch 14/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8292 - dice_coefficient: 0.1855 - iou_metric: 0.7323 - loss: 1.7038
# Epoch 14: val_dice_coefficient improved from 0.17142 to 0.18515, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.8291 - dice_coefficient: 0.1855 - iou_metric: 0.7321 - loss: 1.7037 - val_accuracy: 0.8657 - val_dice_coefficient: 0.1851 - val_iou_metric: 0.7645 - val_loss: 1.6052 - learning_rate: 1.0000e-04
# Epoch 15/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8298 - dice_coefficient: 0.1912 - iou_metric: 0.7325 - loss: 1.6784
# Epoch 15: val_dice_coefficient improved from 0.18515 to 0.18562, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.8298 - dice_coefficient: 0.1912 - iou_metric: 0.7325 - loss: 1.6782 - val_accuracy: 0.8473 - val_dice_coefficient: 0.1856 - val_iou_metric: 0.7362 - val_loss: 1.5981 - learning_rate: 1.0000e-04
# Epoch 16/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8334 - dice_coefficient: 0.1934 - iou_metric: 0.7374 - loss: 1.6660
# Epoch 16: val_dice_coefficient improved from 0.18562 to 0.18894, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.8332 - dice_coefficient: 0.1934 - iou_metric: 0.7373 - loss: 1.6659 - val_accuracy: 0.8014 - val_dice_coefficient: 0.1889 - val_iou_metric: 0.6760 - val_loss: 1.6055 - learning_rate: 1.0000e-04
# Epoch 17/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8334 - dice_coefficient: 0.1979 - iou_metric: 0.7368 - loss: 1.6417
# Epoch 17: val_dice_coefficient did not improve from 0.18894
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.8335 - dice_coefficient: 0.1979 - iou_metric: 0.7369 - loss: 1.6415 - val_accuracy: 0.4349 - val_dice_coefficient: 0.1242 - val_iou_metric: 0.2864 - val_loss: 1.9977 - learning_rate: 1.0000e-04
# Epoch 18/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8389 - dice_coefficient: 0.2013 - iou_metric: 0.7455 - loss: 1.6191
# Epoch 18: val_dice_coefficient improved from 0.18894 to 0.20263, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.8389 - dice_coefficient: 0.2013 - iou_metric: 0.7455 - loss: 1.6191 - val_accuracy: 0.8706 - val_dice_coefficient: 0.2026 - val_iou_metric: 0.7719 - val_loss: 1.5391 - learning_rate: 1.0000e-04
# Epoch 19/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8466 - dice_coefficient: 0.2088 - iou_metric: 0.7546 - loss: 1.5956
# Epoch 19: val_dice_coefficient improved from 0.20263 to 0.21795, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.8466 - dice_coefficient: 0.2088 - iou_metric: 0.7546 - loss: 1.5956 - val_accuracy: 0.8825 - val_dice_coefficient: 0.2179 - val_iou_metric: 0.7916 - val_loss: 1.4731 - learning_rate: 1.0000e-04
# Epoch 20/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8417 - dice_coefficient: 0.2122 - iou_metric: 0.7470 - loss: 1.5817
# Epoch 20: val_dice_coefficient did not improve from 0.21795
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.8417 - dice_coefficient: 0.2121 - iou_metric: 0.7470 - loss: 1.5817 - val_accuracy: 0.8068 - val_dice_coefficient: 0.2007 - val_iou_metric: 0.6841 - val_loss: 1.5439 - learning_rate: 1.0000e-04
# Epoch 21/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8563 - dice_coefficient: 0.2164 - iou_metric: 0.7650 - loss: 1.5392
# Epoch 21: val_dice_coefficient did not improve from 0.21795
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8562 - dice_coefficient: 0.2164 - iou_metric: 0.7650 - loss: 1.5394 - val_accuracy: 0.8820 - val_dice_coefficient: 0.2054 - val_iou_metric: 0.7912 - val_loss: 1.5189 - learning_rate: 1.0000e-04
# Epoch 22/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8569 - dice_coefficient: 0.2233 - iou_metric: 0.7686 - loss: 1.5280
# Epoch 22: val_dice_coefficient did not improve from 0.21795
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8568 - dice_coefficient: 0.2232 - iou_metric: 0.7684 - loss: 1.5283 - val_accuracy: 0.7753 - val_dice_coefficient: 0.1944 - val_iou_metric: 0.6442 - val_loss: 1.5662 - learning_rate: 1.0000e-04
# Epoch 23/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8483 - dice_coefficient: 0.2189 - iou_metric: 0.7574 - loss: 1.5471
# Epoch 23: val_dice_coefficient did not improve from 0.21795
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.8484 - dice_coefficient: 0.2190 - iou_metric: 0.7574 - loss: 1.5467 - val_accuracy: 0.8402 - val_dice_coefficient: 0.2126 - val_iou_metric: 0.7277 - val_loss: 1.4700 - learning_rate: 1.0000e-04
# Epoch 24/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8557 - dice_coefficient: 0.2254 - iou_metric: 0.7673 - loss: 1.5081
# Epoch 24: val_dice_coefficient did not improve from 0.21795
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8557 - dice_coefficient: 0.2254 - iou_metric: 0.7673 - loss: 1.5081 - val_accuracy: 0.8430 - val_dice_coefficient: 0.2044 - val_iou_metric: 0.7313 - val_loss: 1.4963 - learning_rate: 1.0000e-04
# Epoch 25/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8551 - dice_coefficient: 0.2295 - iou_metric: 0.7671 - loss: 1.5047
# Epoch 25: val_dice_coefficient did not improve from 0.21795
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8551 - dice_coefficient: 0.2295 - iou_metric: 0.7671 - loss: 1.5046 - val_accuracy: 0.6571 - val_dice_coefficient: 0.1690 - val_iou_metric: 0.5054 - val_loss: 1.7234 - learning_rate: 1.0000e-04
# Epoch 26/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8582 - dice_coefficient: 0.2336 - iou_metric: 0.7698 - loss: 1.4814
# Epoch 26: val_dice_coefficient improved from 0.21795 to 0.21886, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.8582 - dice_coefficient: 0.2336 - iou_metric: 0.7698 - loss: 1.4814 - val_accuracy: 0.8463 - val_dice_coefficient: 0.2189 - val_iou_metric: 0.7354 - val_loss: 1.4325 - learning_rate: 1.0000e-04
# Epoch 27/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8597 - dice_coefficient: 0.2357 - iou_metric: 0.7725 - loss: 1.4821
# Epoch 27: val_dice_coefficient improved from 0.21886 to 0.23503, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.8597 - dice_coefficient: 0.2357 - iou_metric: 0.7725 - loss: 1.4818 - val_accuracy: 0.8639 - val_dice_coefficient: 0.2350 - val_iou_metric: 0.7610 - val_loss: 1.3778 - learning_rate: 1.0000e-04
# Epoch 28/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8633 - dice_coefficient: 0.2426 - iou_metric: 0.7770 - loss: 1.4438
# Epoch 28: val_dice_coefficient improved from 0.23503 to 0.24251, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.8633 - dice_coefficient: 0.2426 - iou_metric: 0.7770 - loss: 1.4438 - val_accuracy: 0.8824 - val_dice_coefficient: 0.2425 - val_iou_metric: 0.7906 - val_loss: 1.3510 - learning_rate: 1.0000e-04
# Epoch 29/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8598 - dice_coefficient: 0.2392 - iou_metric: 0.7722 - loss: 1.4498
# Epoch 29: val_dice_coefficient did not improve from 0.24251
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.8598 - dice_coefficient: 0.2392 - iou_metric: 0.7723 - loss: 1.4497 - val_accuracy: 0.8829 - val_dice_coefficient: 0.2384 - val_iou_metric: 0.7913 - val_loss: 1.3634 - learning_rate: 1.0000e-04
# Epoch 30/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8585 - dice_coefficient: 0.2461 - iou_metric: 0.7710 - loss: 1.4518
# Epoch 30: val_dice_coefficient improved from 0.24251 to 0.25222, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8585 - dice_coefficient: 0.2460 - iou_metric: 0.7710 - loss: 1.4516 - val_accuracy: 0.8861 - val_dice_coefficient: 0.2522 - val_iou_metric: 0.7972 - val_loss: 1.3353 - learning_rate: 1.0000e-04
# Epoch 31/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8666 - dice_coefficient: 0.2525 - iou_metric: 0.7812 - loss: 1.4161
# Epoch 31: val_dice_coefficient did not improve from 0.25222
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.8666 - dice_coefficient: 0.2525 - iou_metric: 0.7812 - loss: 1.4161 - val_accuracy: 0.8771 - val_dice_coefficient: 0.2213 - val_iou_metric: 0.7869 - val_loss: 1.4683 - learning_rate: 1.0000e-04
# Epoch 32/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8588 - dice_coefficient: 0.2472 - iou_metric: 0.7718 - loss: 1.4373
# Epoch 32: val_dice_coefficient did not improve from 0.25222
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8588 - dice_coefficient: 0.2473 - iou_metric: 0.7718 - loss: 1.4370 - val_accuracy: 0.8730 - val_dice_coefficient: 0.2508 - val_iou_metric: 0.7748 - val_loss: 1.3292 - learning_rate: 1.0000e-04
# Epoch 33/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8654 - dice_coefficient: 0.2558 - iou_metric: 0.7792 - loss: 1.4203
# Epoch 33: val_dice_coefficient did not improve from 0.25222
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.8654 - dice_coefficient: 0.2558 - iou_metric: 0.7793 - loss: 1.4202 - val_accuracy: 0.8677 - val_dice_coefficient: 0.2495 - val_iou_metric: 0.7664 - val_loss: 1.3229 - learning_rate: 1.0000e-04
# Epoch 34/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8649 - dice_coefficient: 0.2510 - iou_metric: 0.7798 - loss: 1.4113
# Epoch 34: val_dice_coefficient did not improve from 0.25222
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8648 - dice_coefficient: 0.2510 - iou_metric: 0.7797 - loss: 1.4115 - val_accuracy: 0.8813 - val_dice_coefficient: 0.2415 - val_iou_metric: 0.7925 - val_loss: 1.3919 - learning_rate: 1.0000e-04
# Epoch 35/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8660 - dice_coefficient: 0.2572 - iou_metric: 0.7818 - loss: 1.4022
# Epoch 35: val_dice_coefficient did not improve from 0.25222
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8660 - dice_coefficient: 0.2572 - iou_metric: 0.7818 - loss: 1.4021 - val_accuracy: 0.7637 - val_dice_coefficient: 0.2064 - val_iou_metric: 0.6284 - val_loss: 1.5335 - learning_rate: 1.0000e-04
# Epoch 36/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8711 - dice_coefficient: 0.2615 - iou_metric: 0.7870 - loss: 1.3829
# Epoch 36: val_dice_coefficient did not improve from 0.25222
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.8710 - dice_coefficient: 0.2615 - iou_metric: 0.7870 - loss: 1.3829 - val_accuracy: 0.8273 - val_dice_coefficient: 0.2308 - val_iou_metric: 0.7090 - val_loss: 1.3958 - learning_rate: 1.0000e-04
# Epoch 37/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8677 - dice_coefficient: 0.2586 - iou_metric: 0.7836 - loss: 1.3763
# Epoch 37: val_dice_coefficient improved from 0.25222 to 0.25686, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.8677 - dice_coefficient: 0.2586 - iou_metric: 0.7837 - loss: 1.3763 - val_accuracy: 0.8733 - val_dice_coefficient: 0.2569 - val_iou_metric: 0.7748 - val_loss: 1.2924 - learning_rate: 1.0000e-04
# Epoch 38/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8702 - dice_coefficient: 0.2646 - iou_metric: 0.7868 - loss: 1.3698
# Epoch 38: val_dice_coefficient did not improve from 0.25686
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8701 - dice_coefficient: 0.2645 - iou_metric: 0.7867 - loss: 1.3698 - val_accuracy: 0.8752 - val_dice_coefficient: 0.2409 - val_iou_metric: 0.7781 - val_loss: 1.3359 - learning_rate: 1.0000e-04
# Epoch 39/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8729 - dice_coefficient: 0.2670 - iou_metric: 0.7907 - loss: 1.3546
# Epoch 39: val_dice_coefficient improved from 0.25686 to 0.26347, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.8728 - dice_coefficient: 0.2670 - iou_metric: 0.7906 - loss: 1.3546 - val_accuracy: 0.8820 - val_dice_coefficient: 0.2635 - val_iou_metric: 0.7889 - val_loss: 1.2678 - learning_rate: 1.0000e-04
# Epoch 40/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8641 - dice_coefficient: 0.2655 - iou_metric: 0.7788 - loss: 1.3710
# Epoch 40: val_dice_coefficient did not improve from 0.26347
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.8642 - dice_coefficient: 0.2655 - iou_metric: 0.7789 - loss: 1.3709 - val_accuracy: 0.8430 - val_dice_coefficient: 0.2399 - val_iou_metric: 0.7283 - val_loss: 1.3647 - learning_rate: 1.0000e-04
# Epoch 41/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8769 - dice_coefficient: 0.2758 - iou_metric: 0.7955 - loss: 1.3276
# Epoch 41: val_dice_coefficient did not improve from 0.26347
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8768 - dice_coefficient: 0.2757 - iou_metric: 0.7954 - loss: 1.3278 - val_accuracy: 0.8813 - val_dice_coefficient: 0.2385 - val_iou_metric: 0.7881 - val_loss: 1.3514 - learning_rate: 1.0000e-04
# Epoch 42/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8720 - dice_coefficient: 0.2704 - iou_metric: 0.7896 - loss: 1.3472
# Epoch 42: val_dice_coefficient did not improve from 0.26347
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.8720 - dice_coefficient: 0.2703 - iou_metric: 0.7896 - loss: 1.3471 - val_accuracy: 0.8588 - val_dice_coefficient: 0.2496 - val_iou_metric: 0.7523 - val_loss: 1.3030 - learning_rate: 1.0000e-04
# Epoch 43/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8712 - dice_coefficient: 0.2760 - iou_metric: 0.7875 - loss: 1.3406
# Epoch 43: val_dice_coefficient did not improve from 0.26347
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8712 - dice_coefficient: 0.2759 - iou_metric: 0.7875 - loss: 1.3407 - val_accuracy: 0.8851 - val_dice_coefficient: 0.2602 - val_iou_metric: 0.7945 - val_loss: 1.2800 - learning_rate: 1.0000e-04
# Epoch 44/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8723 - dice_coefficient: 0.2751 - iou_metric: 0.7891 - loss: 1.3354
# Epoch 44: val_dice_coefficient did not improve from 0.26347
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8723 - dice_coefficient: 0.2751 - iou_metric: 0.7890 - loss: 1.3354 - val_accuracy: 0.8632 - val_dice_coefficient: 0.2584 - val_iou_metric: 0.7593 - val_loss: 1.2834 - learning_rate: 1.0000e-04
# Epoch 45/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8771 - dice_coefficient: 0.2759 - iou_metric: 0.7955 - loss: 1.3239
# Epoch 45: val_dice_coefficient did not improve from 0.26347
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.8771 - dice_coefficient: 0.2759 - iou_metric: 0.7955 - loss: 1.3238 - val_accuracy: 0.8582 - val_dice_coefficient: 0.2518 - val_iou_metric: 0.7511 - val_loss: 1.2967 - learning_rate: 1.0000e-04
# Epoch 46/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8738 - dice_coefficient: 0.2799 - iou_metric: 0.7914 - loss: 1.3165
# Epoch 46: val_dice_coefficient did not improve from 0.26347
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8738 - dice_coefficient: 0.2799 - iou_metric: 0.7914 - loss: 1.3165 - val_accuracy: 0.8595 - val_dice_coefficient: 0.2485 - val_iou_metric: 0.7539 - val_loss: 1.3158 - learning_rate: 1.0000e-04
# Epoch 47/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8692 - dice_coefficient: 0.2753 - iou_metric: 0.7850 - loss: 1.3478
# Epoch 47: val_dice_coefficient did not improve from 0.26347
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8692 - dice_coefficient: 0.2753 - iou_metric: 0.7850 - loss: 1.3476 - val_accuracy: 0.6940 - val_dice_coefficient: 0.1913 - val_iou_metric: 0.5362 - val_loss: 1.6597 - learning_rate: 1.0000e-04
# Epoch 48/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8790 - dice_coefficient: 0.2805 - iou_metric: 0.7984 - loss: 1.3000
# Epoch 48: val_dice_coefficient did not improve from 0.26347
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.8789 - dice_coefficient: 0.2805 - iou_metric: 0.7983 - loss: 1.3001 - val_accuracy: 0.7888 - val_dice_coefficient: 0.2201 - val_iou_metric: 0.6581 - val_loss: 1.4297 - learning_rate: 1.0000e-04
# Epoch 49/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8701 - dice_coefficient: 0.2812 - iou_metric: 0.7859 - loss: 1.3180
# Epoch 49: val_dice_coefficient did not improve from 0.26347
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8701 - dice_coefficient: 0.2812 - iou_metric: 0.7859 - loss: 1.3180 - val_accuracy: 0.5591 - val_dice_coefficient: 0.1594 - val_iou_metric: 0.3950 - val_loss: 1.9004 - learning_rate: 1.0000e-04
# Epoch 50/50
# 103/105 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8771 - dice_coefficient: 0.2838 - iou_metric: 0.7958 - loss: 1.3075
# Epoch 50: val_dice_coefficient did not improve from 0.26347
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8771 - dice_coefficient: 0.2837 - iou_metric: 0.7958 - loss: 1.3073 - val_accuracy: 0.8840 - val_dice_coefficient: 0.2475 - val_iou_metric: 0.7933 - val_loss: 1.3198 - learning_rate: 1.0000e-04
# Visualizando predicciones...
# Visualizing 4 samples from the validation set...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# ¡Entrenamiento completado! El mejor modelo se guardó como 'best_weed_model.h5'
# Evaluando el modelo final en el conjunto de validación:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8882 - dice_coefficient: 0.2702 - iou_metric: 0.8072 - loss: 1.2495
# Validation Loss: 1.2678
# Validation Dice Coefficient: 0.2635
# Validation IoU: 0.7889
# Validation Accuracy: 0.8820
# IoU for Background: 0.8747
# IoU for Cow-tongue: 0.7634
# IoU for Dandelion: 0.7188
# IoU for Kikuyo: 0.7054
# IoU for Other: 0.6384
# IoU for Potato: 0.3888
